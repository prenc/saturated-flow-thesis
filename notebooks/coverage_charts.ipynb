# %%
import math
import os
import warnings
from glob import glob
from itertools import cycle

import matplotlib.pyplot as plt
plt.style.use("grayscale")
font = {'family' : 'normal',
        # 'weight' : 'bold',
        'size'   : 20}
plt.rc('font', **font)

import numpy as np
import pandas as pd
from scipy.interpolate import make_interp_spline
warnings.filterwarnings('ignore')
# Out:
# /Users/tomaszpecak/.pyenv/versions/3.9.2/lib/python3.9/site-packages/pandas/compat/__init__.py:97: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
def rounddown(x):
     return int(math.ceil(x / 100.0)) * 100 - 100

def get_column_from_many_csv(filenames, col_num):
    intermediate_df = pd.DataFrame()
    for i, path in enumerate(filenames):
        df = pd.read_csv(path, skiprows=1)
        intermediate_df[i] = df.iloc[:, col_num]
    return intermediate_df

# %%
def smoothen_plot(x, y, smooth_power=300):
    smoothened_x = np.linspace(x.min(), x.max(), smooth_power)
    spl = make_interp_spline(x, y, k=3)
    smoothened_y = spl(smoothened_x)
    return smoothened_x, smoothened_y

# %%
def read_more_averaging_data(dir_path = "results/paper/coverage/coverage_extreme", data_column=2, path="*sc_stress_*", func=np.min):
    atomic = glob(f"{dir_path}/{path}/*")
    df = pd.read_csv(atomic[0], skiprows=2, names=['iteration_no', 'ac_coverage', 'ac_iter_time'])
    df.drop(['ac_iter_time'], axis=1, inplace=True)
    for test_data in sorted(glob(f"{dir_path}/*")):
        data = glob(f"{test_data}/*")
        df[os.path.basename(test_data)] = func(get_column_from_many_csv(data, data_column), axis=1)

    return df

# %%
def create_plot_ac_comp(df, cumulative=False, clean=3, smooth = 100, cross_pairs=[]):
    fig, ax = plt.subplots(figsize=(15, 6))

    iteration_no = df['iteration_no']
    ac_coverage = df["ac_coverage"]

    df.drop(['iteration_no','ac_coverage',], axis=1, inplace=True)

    if smooth != -1:
        smooth_df = pd.DataFrame()
        for time in df:
            _, ac_iter_time_smooth = smoothen_plot(iteration_no, df[time], smooth)
            smooth_df[time] = ac_iter_time_smooth
        iteration_no_smooth, ac_coverage_smooth = smoothen_plot(iteration_no, ac_coverage, smooth)
        smooth_iteration_no = iteration_no_smooth
        smooth_ac_coverage = ac_coverage_smooth
    else:
        smooth_iteration_no = iteration_no.to_numpy()
        smooth_ac_coverage = ac_coverage.to_numpy()
        smooth_df = df

    ax.set_xlabel('Iteration', fontsize=20)
    if cumulative:
        ax.set_ylabel('Elapsed time [s]',fontsize=20)
        normalized_df = smooth_df.apply(lambda x: x / (10**9))
        normalized_df = normalized_df.apply(lambda x: x.cumsum())
    else:
        ax.set_ylabel('Time of 10 iterations [ms]',fontsize=20)
        normalized_df = smooth_df.apply(lambda x: x / (10**6))

    line_styles = cycle([":", "--", "-.", "-"])
    marker_styles = cycle(("X", "o", "*", "+", "*", "X", ".", "x"))
    for file_name_with_params in normalized_df:
        ax.plot(smooth_iteration_no,
                normalized_df[file_name_with_params],
                linestyle=next(line_styles),
                marker=next(marker_styles),
                label=file_name_with_params,
                )
    full_grid = np.where(smooth_ac_coverage >= 1.0)[0][0]

    cross_points = []
    for (cross1, cross2) in cross_pairs:
        diff_list = (normalized_df[cross1] - normalized_df[cross2]).abs()
        cross_point = np.where(diff_list < 1)[0][0]
        cross_points.append(cross_point)
        ax.axvline(x=smooth_iteration_no[cross_point], lw=1, ls='--', c='black')
        y_lim = ax.get_ylim()
        x_lim = ax.get_xlim()
        ax.text(smooth_iteration_no[cross_point] - x_lim[1] * .02,
                (y_lim[1] - y_lim[0]) * .05 + y_lim[0],
                'Iteration time crossover', rotation=90)

    xs = (
      [full_grid - 2] +
      list(range(0, len(smooth_iteration_no) , round(len(smooth_iteration_no) / 6) ))

    )
    xs.pop()
    xs.extend(cross_points)
    xticks = [smooth_iteration_no[i]  for i in xs]


    ax.set_xticks([rounddown(i) for i in xticks])

    secax = ax.secondary_xaxis('top')
    secax.set_xlabel('Fraction of active cells in CA', fontsize=20, labelpad=10)

    secax.set_xticks(xticks)
    secax.set_xticklabels([
        f'{smooth_ac_coverage[i] * 100:.0f}%'
        for i in xs
    ])

    plt.legend()
    return fig

# %%
df = read_more_averaging_data(dir_path = "results/paper/coverage/extreme", path="*naive_4*")

create_plot_ac_comp(df, smooth=50)
plt.savefig("coverage_stress.pdf")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-62503fd5adb3> in <module>
#       1 df = read_more_averaging_data(dir_path = "results/paper/coverage/extreme", path="*naive_4*")
#       2
# ----> 3 create_plot_ac_comp(df, smooth=50)
#       4 plt.savefig("coverage_stress.pdf")
#       5
#
# <ipython-input-5-520e6d1f8bf6> in create_plot_ac_comp(df, cumulative, clean, smooth, cross_pairs)
#      38                 label=file_name_with_params,
#      39                 )
# ---> 40     full_grid = np.where(smooth_ac_coverage >= 1.0)[0][0]
#      41
#      42     cross_points = []
#
# IndexError: index 0 is out of bounds for axis 0 with size 0
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.

# %%
df = read_more_averaging_data(dir_path = "results/paper/coverage/normal", path="*sc_4*")
print(df)

create_plot_ac_comp(df, smooth=50, cross_pairs=[("AC SC imp.", "Non-AC standard imp.")])
plt.savefig("coverage.pdf")
# Out:
#                         iteration_no  ac_coverage  ac_u_sc_4000_4500_8_0_1  \
# 19   0.003044 17742786       1032356       706637                      NaN
# 29   0.006820 11158215        102582       712565                      NaN
# 39   0.011204 12111113         82743       716105                      NaN
# 49   0.014928 9997932          67728       710191                      NaN
# 59   0.018392 10412407         98659       717602                      NaN
# ...                              ...          ...                      ...
# 4459 1.000000 19240228       1923070       887422                      NaN
# 4469 1.000000 19232336       1922891       887422                      NaN
# 4479 1.000000 19243632       1924851       887422                      NaN
# 4489 1.000000 19245558       1922048       887422                      NaN
# 4499 1.000000 19239566       1924922       887422                      NaN
#
#                         ac_u_sc_adaptive_4000_4500_8_0_1  \
# 19   0.003044 17742786                               NaN
# 29   0.006820 11158215                               NaN
# 39   0.011204 12111113                               NaN
# 49   0.014928 9997932                                NaN
# 59   0.018392 10412407                               NaN
# ...                                                  ...
# 4459 1.000000 19240228                               NaN
# 4469 1.000000 19232336                               NaN
# 4479 1.000000 19243632                               NaN
# 4489 1.000000 19245558                               NaN
# 4499 1.000000 19239566                               NaN
#
#                         u_standard_4000_4500_8_0_1
# 19   0.003044 17742786                         NaN
# 29   0.006820 11158215                         NaN
# 39   0.011204 12111113                         NaN
# 49   0.014928 9997932                          NaN
# 59   0.018392 10412407                         NaN
# ...                                            ...
# 4459 1.000000 19240228                         NaN
# 4469 1.000000 19232336                         NaN
# 4479 1.000000 19243632                         NaN
# 4489 1.000000 19245558                         NaN
# 4499 1.000000 19239566                         NaN
#
# [449 rows x 5 columns]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-ed463918f41c> in <module>
#       2 print(df)
#       3
# ----> 4 create_plot_ac_comp(df, smooth=50, cross_pairs=[("AC SC imp.", "Non-AC standard imp.")])
#       5 plt.savefig("coverage.pdf")
#       6
#
# <ipython-input-5-520e6d1f8bf6> in create_plot_ac_comp(df, cumulative, clean, smooth, cross_pairs)
#      10         smooth_df = pd.DataFrame()
#      11         for time in df:
# ---> 12             _, ac_iter_time_smooth = smoothen_plot(iteration_no, df[time], smooth)
#      13             smooth_df[time] = ac_iter_time_smooth
#      14         iteration_no_smooth, ac_coverage_smooth = smoothen_plot(iteration_no, ac_coverage, smooth)
#
# <ipython-input-3-7a50cc5283a5> in smoothen_plot(x, y, smooth_power)
#       1 def smoothen_plot(x, y, smooth_power=300):
#       2     smoothened_x = np.linspace(x.min(), x.max(), smooth_power)
# ----> 3     spl = make_interp_spline(x, y, k=3)
#       4     smoothened_y = spl(smoothened_x)
#       5     return smoothened_x, smoothened_y
#
# ~/.pyenv/versions/3.9.2/lib/python3.9/site-packages/scipy/interpolate/_bsplines.py in make_interp_spline(x, y, k, t, bc_type, axis, check_finite)
#     761
#     762     x = _as_float_array(x, check_finite)
# --> 763     y = _as_float_array(y, check_finite)
#     764     k = operator.index(k)
#     765
#
# ~/.pyenv/versions/3.9.2/lib/python3.9/site-packages/scipy/interpolate/_bsplines.py in _as_float_array(x, check_finite)
#      30     x = x.astype(dtyp, copy=False)
#      31     if check_finite and not np.isfinite(x).all():
# ---> 32         raise ValueError("Array must not contain infs or nans.")
#      33     return x
#      34
#
# ValueError: Array must not contain infs or nans.

# %%
df = read_more_averaging_data(dir_path = "results/paper/coverage/stress", path="*sc_4*")
df.columns = ["iteration_no", "ac_coverage", "AC SC imp.", "AC SC adaptive imp.", "Non-AC standard imp."]

create_plot_ac_comp(df, smooth=50, cumulative=True)
plt.savefig("coverage_cumulative.pdf")
